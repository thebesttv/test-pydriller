# %%
import pandas as pd

# Specify the path to your CSV file
csv_file_path = "../MSR_20_Code_vulnerability_CSV_Dataset/all_c_cpp_release2.0.csv"

# Use pd.read_csv() to open and read the CSV file into a DataFrame
data = pd.read_csv(csv_file_path)

# %%
data.head()
# Out:
#    Unnamed: 0 authentication_required availability_impact         cve_id  \
# 0           0            Not required             Partial  CVE-2009-1194
# 1           1            Not required             Partial  CVE-2010-2809
# 2           2            Not required             Partial  CVE-2010-2060
# 3           3            Not required             Partial  CVE-2010-1155
# 4           4            Not required             Partial  CVE-2010-1152
#
#                                         cve_page   cwe_id access_complexity  \
# 0  https://www.cvedetails.com/cve/CVE-2009-1194/  CWE-189            Medium
# 1  https://www.cvedetails.com/cve/CVE-2010-2809/   CWE-94            Medium
# 2  https://www.cvedetails.com/cve/CVE-2010-2060/      NaN               Low
# 3  https://www.cvedetails.com/cve/CVE-2010-1155/   CWE-20            Medium
# 4  https://www.cvedetails.com/cve/CVE-2010-1152/   CWE-20               Low
#
# ...

# %%
# 有306个cve_id是NaN的
data.cve_id.isna().sum()
# Out:
# 306

# %%
# 而且这些都与 chromium 有关
data[data.cve_id.isna()].ref_link.str.contains('chromium').sum()
# Out:
# 306

# %%
# 先去掉这些空的
data = data[~data.cve_id.isna()]

# %%
# 这些是和 chromium 有关的
data[data.ref_link.str.contains('github.com/chromium/chromium')]
# Out:
#       Unnamed: 0 authentication_required availability_impact         cve_id  \
# 3013        3013            Not required             Partial  CVE-2011-3903
# 3014        3014            Not required             Partial  CVE-2011-3906
# 3015        3015            Not required                 NaN  CVE-2011-3907
# 3016        3016            Not required             Partial  CVE-2011-3909
# 3017        3017            Not required             Partial  CVE-2011-3911
# ...          ...                     ...                 ...            ...
# 4427        4427            Not required             Partial  CVE-2016-1691
# 4428        4428            Not required                 NaN  CVE-2016-1692
# 4429        4429            Not required                 NaN  CVE-2016-1693
# 4430        4430            Not required                 NaN  CVE-2016-1694
# 4431        4431            Not required             Partial  CVE-2016-1695
#
# ...

# %%
# 这些与android有关
data[data.ref_link.str.contains('https://android.googlesource.com')]
# Out:
#       Unnamed: 0 authentication_required availability_impact         cve_id  \
# 2538        2538            Not required                 NaN  CVE-2014-8610
# 2539        2539            Not required            Complete  CVE-2014-8609
# 2540        2540            Not required             Partial  CVE-2014-8507
# 2541        2541            Not required            Complete  CVE-2014-7911
# 2542        2542            Not required            Complete  CVE-2015-6575
# ...          ...                     ...                 ...            ...
# 2909        2909            Not required                 NaN  CVE-2018-9502
# 2910        2910            Not required                 NaN  CVE-2018-9493
# 2911        2911            Not required                 NaN  CVE-2018-9493
# 2912        2912            Not required            Complete  CVE-2018-9490
# 2913        2913            Not required             Partial  CVE-2018-9452
#
# ...

# %%
# Android & CWE-772
data[data.ref_link.str.contains('https://android.googlesource.com') & data.cwe_id.str.contains('CWE-772')]
# Out:
#       Unnamed: 0 authentication_required availability_impact         cve_id  \
# 2758        2758            Not required            Complete  CVE-2017-0818
# 2762        2762            Not required             Partial  CVE-2017-0813
#
#                                            cve_page   cwe_id  \
# 2758  https://www.cvedetails.com/cve/CVE-2017-0818/  CWE-772
# 2762  https://www.cvedetails.com/cve/CVE-2017-0813/  CWE-772
#
#      access_complexity confidentiality_impact integrity_impact publish_date  \
# 2758               Low                    NaN              NaN   2017-10-03
# 2762               Low                    NaN              NaN   2017-10-03
#
#       ...  update_date vulnerability_classification  \
# 2758  ...   2019-10-02                          NaN
# 2762  ...   2019-10-02                         DoS
#
#                                                ref_link  \
# 2758  https://android.googlesource.com/platform/fram...
# ...

# %%
# Android & CWE-476
data[data.ref_link.str.contains('https://android.googlesource.com') & data.cwe_id.str.contains('CWE-476')]
# Out:
#       Unnamed: 0 authentication_required availability_impact         cve_id  \
# 2640        2640            Not required             Partial  CVE-2016-3821
# 2772        2772            Not required            Complete  CVE-2017-0635
# 2815        2815            Not required             Partial  CVE-2014-7919
#
#                                            cve_page   cwe_id  \
# 2640  https://www.cvedetails.com/cve/CVE-2016-3821/  CWE-476
# 2772  https://www.cvedetails.com/cve/CVE-2017-0635/  CWE-476
# 2815  https://www.cvedetails.com/cve/CVE-2014-7919/  CWE-476
#
#      access_complexity confidentiality_impact integrity_impact publish_date  \
# 2640               Low                Partial          Partial   2016-08-05
# 2772            Medium                    NaN              NaN   2017-05-12
# 2815               Low                    NaN              NaN   2017-06-08
#
#       ...  update_date vulnerability_classification  \
# ...

# %%
# Android & CWE-415
data[data.ref_link.str.contains('https://android.googlesource.com') & data.cwe_id.str.contains('CWE-415')]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, authentication_required, availability_impact, cve_id, cve_page, cwe_id, access_complexity, confidentiality_impact, integrity_impact, publish_date, score, summary, update_date, vulnerability_classification, ref_link, commit_id, commit_message, files_changed, lang, project, version_after_fix, version_before_fix]
# Index: []
#
# [0 rows x 22 columns]
